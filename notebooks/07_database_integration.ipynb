# %% [markdown]
# ## Objective
#
# The objective of this notebook is to integrate the final feature-engineered dataset with a MySQL database. Storing the dataset in a relational database enables efficient querying, supports SQL-based business analysis, and provides a reliable data source for Power BI dashboards.

# %% [markdown]
# ## Business Context
#
# After cleaning, feature engineering, exploratory analysis, and statistical testing, the dataset is ready for storage in a relational database.
#
# Using MySQL allows business users and analysts to:
#
# - Query the data efficiently using SQL.
# - Perform business reporting.
# - Connect directly to Power BI.
# - Maintain a centralized and structured data source.

# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
df=pd.read_csv("C:/Users/RAHUL YADAV/OneDrive/credit-risk-analysis/data/featured/loan_default_cleaned.csv")

df.head()
# Out:
#        loanid  age  income  loanamount  creditscore  monthsemployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    numcreditlines  interestrate  loanterm  dtiratio  ... maritalstatus  \
# 0               4         15.23        36      0.44  ...      Divorced
# 1               1          4.81        60      0.68  ...       Married
# 2               3         21.17        24      0.31  ...      Divorced
# 3               3          7.07        24      0.23  ...       Married
# 4               4          6.51        48      0.73  ...      Divorced
#
#   hasmortgage hasdependents loanpurpose hascosigner default agegroup  \
# ...

# %%
df.shape
# Out:
# (255347, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   loanid           255347 non-null  object
#  1   age              255347 non-null  int64
#  2   income           255347 non-null  int64
#  3   loanamount       255347 non-null  int64
#  4   creditscore      255347 non-null  int64
#  5   monthsemployed   255347 non-null  int64
#  6   numcreditlines   255347 non-null  int64
#  7   interestrate     255347 non-null  float64
#  8   loanterm         255347 non-null  int64
#  9   dtiratio         255347 non-null  float64
#  10  education        255347 non-null  object
#  11  employmenttype   255347 non-null  object
#  12  maritalstatus    255347 non-null  object
#  13  hasmortgage      255347 non-null  object
#  14  hasdependents    255347 non-null  object
#  15  loanpurpose      255347 non-null  object
# ...

# %%
username = "root"
password = "Rahul2005"
host = "localhost"
port = "3306"
database = "credit_risk_analysis"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

# %%
df.to_sql(
    name="loan_default",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data imported successfully!")
# Out:
# Data imported successfully!

# %% [markdown]
# ## Business Conclusion
#
# The feature-engineered loan dataset has been successfully integrated into MySQL. The database now serves as the central source for SQL analysis and Power BI reporting. Storing the data in a relational database improves accessibility, supports efficient querying, and enables scalable business intelligence workflows.

# %% [markdown]
# ## Summary
#
# In this notebook:
#
# - Connected Python to MySQL.
# - Loaded the feature-engineered dataset.
# - Imported the dataset into the `loan_default` table.
# - Verified the successful import.
# - Prepared the database for SQL analysis and dashboard development.
